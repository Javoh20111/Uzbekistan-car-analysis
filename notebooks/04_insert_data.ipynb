# %%
# !pip install pandas sqlalchemy psycopg2-binary

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('postgresql://postgres:8228@localhost:5432/cars_db')

# %%
df = pd.read_csv('/Users/javohireshonov/Desktop/Study/Projects/Uzbekistan car postings /data/Prepared/brands.csv')

df.to_sql(
    'brands',
    engine,
    if_exists='append',
    index=False
)
# Out:
# 19

# %%
df = pd.read_csv('/Users/javohireshonov/Desktop/Study/Projects/Uzbekistan car postings /data/Prepared/sale_options.csv')

df.to_sql(
    'sale_options',
    engine,
    if_exists='append',
    index=False
)
# Out:
# 11

# %% [markdown]
# I decide to continue this work on notebooks/  03_database_preparation.ipynb file because it is easier
