# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_json('../data/Prepared/car_data.json')

# %% [markdown]
# ## Data contract (Data Dictionary + Validity Rules)

# %% [markdown]
# The dataset in `data/raw/car_data.json` and `data/Prepared/car_data.json` currently uses the same column schema. The table below documents the expected meaning, type, and validation rules for each field.
#
# So this works as checklist when cleaning data.
#
# | Column | Meaning | Type | Valid range/values | Units | Notes |
# | --- | --- | --- | --- | --- | --- |
# | `url` | listing URL | string | expected to be a valid OLX posting URL | - | should identify a posting, but duplicates are present in the current data |
# | `posting_date` | date the listing was posted | date string | usually `DD.MM.YYYY`; some rows use relative text such as `Сегодня` | date | must be normalized before date parsing |
# | `region` | seller region in Uzbekistan | category | 13 observed region values including `Tashkent`, `Samarkand`, `Bukhara`, `Karakalpakstan` | - | 1 missing value observed |
# | `district` | district or city within a region | category | 230 observed values | - | spelling and naming normalization may be needed |
# | `price` | listed sale price | numeric stored as string | positive values; observed range `10,000,000` to `2,008,972,671` | local currency | 5 missing values observed; outliers should be reviewed |
# | `currency` | currency code for `price` | category | mostly `UZS` when present | ISO currency code | highly sparse in the current data; many rows are missing |
# | `description` | free-text ad description | text | arbitrary seller-written text | - | noisy multilingual text; useful for NLP/features after cleaning |
# | `image_url` | main image link for the ad | string | expected `http`/`https` image URL | - | optional; missing values are present |
# | `seller_type` | seller classification | category | mostly `private` in observed data | - | many missing values; could later include dealer/business labels |
# | `model` | vehicle model name | category/text | 720 observed values | - | may mix trims, generations, and inconsistent naming |
# | `body_type` | vehicle body style | category | `Sedan`, `Hatchback`, `Station Wagon`, `SUV`, `Minivan`, `Pickup`, `Coupe`, `Convertible`, `Other` | - | appears complete in the current snapshot |
# | `sale_type` | sale terms attached to the listing | multi-label text/category | values such as `Simple Sale`, `Credit`, `Installment`, `Exchange`, `Rent`, often comma-separated combinations | - | multilingual and highly inconsistent; many missing values |
# | `year` | vehicle manufacture year | integer stored as string | observed range `1900` to `2025` | year | should be checked against realistic car production years |
# | `mileage` | vehicle mileage | integer stored as string | observed range `0` to `10,000,000` | km | missing values and obvious outliers are possible |
# | `transmission` | gearbox type | category | `Manual`, `Automatic`, `Other` | - | appears complete in the current snapshot |
# | `color` | vehicle color | category | 23 observed color values such as `White`, `Black`, `Gray`, `Blue` | - | synonyms may need consolidation |
# | `engine_volume` | engine size | numeric stored as string | observed range `1` to `10000` | unclear/mixed | scale is inconsistent across rows and likely needs normalization before analysis |
# | `fuel_type` | fuel system | category | `Gasoline/Gas`, `Gasoline`, `Electric`, `Hybrid`, `Diesel`, `Other` | - | appears complete in the current snapshot |
# | `condition` | vehicle condition | category | `Excellent`, `Good`, `Average`, `Needs Repair` | - | ordinal meaning should be preserved if encoded |
# | `owners_count` | number of previous owners | ordinal category stored as string | `1`, `2`, `3`, `4+` | owners | missing values are present; `4+` is grouped rather than exact |
# | `additional_options` | extra features/options listed in the ad | comma-separated text list | examples include `Customs Cleared`, `Electrical Window Lifters`, parking sensors, etc. | - | multi-valued field; multilingual, sparse, and suitable for splitting into tags |

# %% [markdown]
# ## Data intake & first checks

# %% [markdown]
# ### Basic intake checklist:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47106 entries, 0 to 47105
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   url                 47106 non-null  object
#  1   posting_date        47106 non-null  object
#  2   region              47105 non-null  object
#  3   district            47105 non-null  object
#  4   price               47101 non-null  object
#  5   currency            12571 non-null  object
#  6   description         47106 non-null  object
#  7   image_url           45520 non-null  object
#  8   seller_type         39798 non-null  object
#  9   model               47047 non-null  object
#  10  body_type           47106 non-null  object
#  11  sale_type           18713 non-null  object
#  12  year                47106 non-null  int64
#  13  mileage             43818 non-null  float64
#  14  transmission        47106 non-null  object
#  15  color               47106 non-null  object
#  16  engine_volume       47106 non-null  int64
#  17  fuel_type           47106 non-null  object
#  18  condition           47106 non-null  object
#  19  owners_count        42293 non-null  object
#  20  additional_options  30987 non-null  object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 7.9+ MB

# %% [markdown]
# ### Uniqueness + duplicates

# %%
df['url'].nunique()
# Out:
# 46106

# %% [markdown]
# No dublicate found

# %% [markdown]
# ### Target integrity check

# %% [markdown]
# The target variable (price) represents seller-listed prices, which may include noise due to negotiation strategies and inconsistent reporting.

# %% [markdown]
# ##  Data quality audit (prove what’s wrong before fixing)

# %% [markdown]
# Data quality audit
#
# |Column|% missing |Is missing acceptable?|Why might it be missing?|
# |---|---|---|---|
# |currency|73%|No|Scraper could not identify USD currency|
# |sale_type|60%|Maybe|Sales type not included in description|
# |model|1%|No|Model not included in description|
# |mileage|7%|Yes(moderate, manageable)|Seller may be hide high usage, older listings may not include it|
# |additional_options|34%|Yes|User forgot to include or none exist|

# %% [markdown]
# ## Cleaning strategy (not just steps-decisions)

# %%
df.head(100)
# Out:
#                                                   url posting_date  \
# 0   https://olx.uz/d/obyavlenie/vaz-2103-gazda-yur...   26.04.2025
# 1   https://olx.uz/d/obyavlenie/vaz2105zhuguli-god...   26.04.2025
# 2   https://olx.uz/d/obyavlenie/juguli-21011-sotil...   26.04.2025
# 3   https://olx.uz/d/obyavlenie/waxzod-kafolati-bi...   26.04.2025
# 4   https://olx.uz/d/obyavlenie/mazda-626-starushk...   26.04.2025
# ..                                                ...          ...
# 95  https://olx.uz/d/obyavlenie/jiguli-vaz-lada-21...   18.04.2025
# 96  https://olx.uz/d/obyavlenie/zaz-40-lik-dakumen...   18.04.2025
# 97  https://olx.uz/d/obyavlenie/prodam-zhiguli-210...   18.04.2025
# 98  https://olx.uz/d/obyavlenie/ford-scorpio-1-pok...   18.04.2025
# 99  https://olx.uz/d/obyavlenie/yurishga-garitiya-...   18.04.2025
#
#             region                     district     price currency  \
# 0          Jizzakh                    Gallaaral  15000000      UZS
# 1         Namangan                     Namangan  15000000      UZS
# 2          Khorezm                       Karaul  15000000      UZS
# 3          Jizzakh                Mardzhanbulak  15000000      UZS
# 4   Karakalpakstan                      Kungrad  15000000      UZS
# ..             ...                          ...       ...      ...
# 95     Kashkadarya                        Kasan  15000000      UZS
# 96           Navoi                        Navoi  15000000      UZS
# 97        Tashkent                     Tashmore  15000000      UZS
# 98        Tashkent  TashkentYashnabadskiy rayon  15000000      UZS
# 99        Tashkent                   Eshanguzar  15000000      UZS
#
#                                           description  \
# 0           Mator karobka zadnimos qilingan yili 1979
# 1   Торг строга укапота машина на ходу  полный раб...
# 2   Mashin toxlangan metan 100 lik  bo 14  diska b...
# 3   31029 96yil matori zor karopka zor magnitafon ...
# 4   Прадаётсья на запчасти Мазда 626 старушка 1.6 ...
# ..                                                ...
# 95  Mator 06 korobka 4tali benzin da 1996yil narxi...
# 96  запарож 40 лик айби йок балонлар янги мошина д...
# 97  Цвет-синий. В хорошем состоянии. Топливо-бензи...
# 98  Техническое состояние хорошее, \nВ этом году б...
# 99  Mashina yaxshi xolati o'rta ikala baloni yagi ...
#
#                                             image_url seller_type      model  \
# 0   https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private     : 2103
# 1   https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private     : 2105
# 2   https://frankfurt.apollo.olxcdn.com:443/v1/fil...        None     : 2101
# 3   https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private    : 31029
# 4   https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private      : 626
# ..                                                ...         ...        ...
# 95  https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private     : 2106
# 96  https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private     : 1140
# 97                                               None     private     : 2106
# 98  https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private  : Scorpio
# 99  https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private     : 2106
#
#     ...    sale_type  year   mileage  transmission  color engine_volume  \
# 0   ...         None  1979       NaN        Manual    Red            12
# 1   ...  Simple Sale  1982   72122.0        Manual  Green             1
# 2   ...         None  1979       0.0        Manual  White          2103
# 3   ...         None  1996     560.0        Manual  White           105
# 4   ...  Simple Sale  1986       NaN        Manual  White            16
# ..  ...          ...   ...       ...           ...    ...           ...
# 95  ...  Simple Sale  1996  200000.0        Manual  White             1
# 96  ...         None  1989  444444.0        Manual  White            41
# 97  ...  Simple Sale  1990   37000.0        Manual   Blue            11
# 98  ...         None  1986       NaN        Manual    Red             2
# 99  ...         None  1984   27000.0        Manual  White            75
#
#        fuel_type     condition owners_count  \
# 0   Gasoline/Gas          Good            2
# 1   Gasoline/Gas       Average            1
# 2   Gasoline/Gas          Good           4+
# 3   Gasoline/Gas          Good            2
# 4   Gasoline/Gas  Needs Repair         None
# ..           ...           ...          ...
# 95      Gasoline       Average            1
# 96      Gasoline          Good            1
# 97      Gasoline          Good            2
# 98      Gasoline          Good            2
# 99  Gasoline/Gas       Average            1
#
#                                    additional_options
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4   Customs Cleared, Electrical Window Lifters, Па...
# ..                                                ...
# 95                                               None
# 96                                               None
# 97                                    Security System
# 98                                               None
# 99                                         Парктроник
#
# [100 rows x 21 columns]

# %% [markdown]
# ### Standardization rules (categorical)

# %% [markdown]
# #### Starting off with `model` column

# %%
df['model'].unique()
# Out:
# array([': 2103', ': 2105', ': 2101', ': 31029', ': 626', ': 2109',
#        ': 2108', ': 412', ': 2107', ': 21', ': 2106', ': 1102 Таврия',
#        ': 2111', ': 2401', ': 2125 Комби', ': Tico', ': Прочее',
#        ': Skyline GT-R', ': 2140', ': 469', ': 69', ': 24', ': Другая',
#        ': 21109', ': 21099', ': Courier', ': 100', ': 1140', ': Scorpio',
#        ': 21011', ': 21111', ': 66', ': Korando', ': 2102', ': Omega',
#        ': 31', ': 3110', ': GE3', ': Ascona', ': 2121 Нива', ': 407',
#        ': Largus', ': 2141', ': 21093', ': Sierra', ': 2715', ': 2110',
#        ': 80', ': Matiz', ': 1117 Kalina универсал', ': 2410', ': 21013',
#        ': 21124', ': Cabriolet', ': ASLK 2137', ': 3102', ': 2104',
#        ': Simbir', ': Patriot', ': 21106', ': Golf', ': 968M', ': Escort',
#        ': 968', ': Taunus', ': 2402', ': Fiesta', ': 21060', ': Uno',
#        ': S3', ': 126', ': Sens', ': 2206', ': Jetta', ': 21051',
#        ': Espero', ': 21061', ': 1118 Kalina седан', ': 401', ': Arcadia',
#        ': Nexia', ': Damas', ': 4x4', ': Aerostar', ': 200', ': 116',
#        ': Mercury', ': ASLK 2140', ': 2137 Kombi', ': AD', ': Hiace',
#        ': 21033', ': Winstorm', ': 520', ': 21083', ': 412 Э', ': 21412',
#        ': 21М', ': 20', ': Transporter', ': 14', ': 3303',
#        ': 23632 Pickup', ': Vectra', ': Croma', ': 1111 Ока', ': 316',
#        ': 2113', ': 1122', ': Bluebird', ': R Nessa', ': 965', ': Rekord',
#        ': 190', ': 469Б', ': Lacetti', ': 2142', ': Passat', ': Accent',
#        ': 2136 Kombi', ': 426', ': 21071', ': 1119 Kalina хэтчбэк',
#        ': 124', ': 21УС', ': 21073', ': 3102i', ': Excel', ': 220',
#        ': 21214 Niva', ': Titan', ': Sonata', ': Pickup', ': Racer',
#        ': 3151', ': 21312', ': Maxima', ': 3159', ': 31512',
#        ': 31512-010', ': 127', ': 2411', ': Falcon', ': Starlet',
#        ': 21063', ': Galant', ': 21065', ': 2115', ': 51', ': 21102',
#        ': Corolla', ': 318', ': Hunter', ': 528', ': 518', ': Kadett',
#        ': M3', ': Taurus', ': Prince', ': Soarer', ': 3105', ': 21101',
#        ': 53', ': 21043', ': 21093i', ': 2138', ': 214120', ': 2131',
#        ': 13 Чайка', ': 31013', ': Leganza', ': Дуэт', ': Transit',
#        ': 21103', ': 21099i', ': 21101i', ': S 500', ': 31514-012',
#        ': eT7', ': Cressida', ': Festiva', ': 2310', ': Golf II',
#        ': 21218 Niva', ': Pregio', ': 320', ': Spider Europa',
#        ': Octavia', ': 535', ': Tempra', ': 31105', ': 180SX',
#        ': 21213 Niva', ': 230', ': Granada', ': Golf I', ': 400',
#        ': Clarus', ': GT-R', ': 52', ': Micra', ': M-20', ': Granta',
#        ': Дана', ': Sunny', ': E 280', ': 21104', ': T-mod', ': Elantra',
#        ': A 190', ': Kadett E', ': 3153', ': 3962', ': E 230',
#        ': Carina 2', ': 2170 Priora', ': 21122', ': 21214i Niva',
#        ': Arena', ': Condor', ': 310221', ': F-150', ': 2500', ': Spark',
#        ': Bongo', ': 22', ': 31519-010', ': Polo Sedan', ': 21074',
#        ': 929', ': Lanos', ': Datsun', ': EK Wagon', ': Express',
#        ': Tacuma', ': Astra', ': 21121', ': Aveo', ': Eterna',
#        ': Town Ace', ': 3160', ': 3111', ': 3163 Patriot', ': RX400h',
#        ': 3741', ': Carina', ': Orion', ': S1', ': 21072', ': Cronos',
#        ': 2114', ': GT', ': 2112', ': Gloria', ': Laurel', ': 31514',
#        ': 31022', ': Astro', ': Caprice', ': 315195 Hunter', ': Shuma',
#        ': Capri', ': Grace', ': 3110i', ': 524', ': Blazer', ': 525',
#        ': Tredia', ': 3162', ': 300', ': Brava', ': 39094', ': Skyline',
#        ': Starex', ': B 200', ': Combo', ': Admiral', ': Camry',
#        ': Seltos', ': 1103', ': Focus ST', ': Focus C-Max', ': А3',
#        ': Classic', ': Altezza', ': Chevelle', ': Almera',
#        ': Town Ace Noah', ': 240', ': 3221', ': 530', ': Quattro',
#        ': D-Max Sahar', ': 434', ': C 230', ': Vito', ': Chance',
#        ': C 180', ': Niva', ': 110308', ': E 500', ': Beretta',
#        ': Streetka', ': 728', ': 2172 Priora', ': Tiburon', ': Epica',
#        ': C-Max', ': Cavalier', ': C 200', ': 118', ': Alero', ': 280',
#        ': A 140', ': 2171 Priora', ': Gentra', ': ARRIZO 6 PRO',
#        ': S 300', ': S 280', ': C10', ': Yaris', ': 250', ': Sportage',
#        ': 325', ': A 210', ': Van', ': Avante', ': Kalina 2',
#        ': H-1 starex', ': CLK 500', ': Rio', ': Cobalt', ': 21114',
#        ': Panda', ': C1500', ': XG', ': А6', ': Getz', ': 315108 Hunter',
#        ': Nubira', ': 21310', ': Chevy Van', ': Cruze', ': 1105',
#        ': Carnival', ': Magnus', ': E 200', ': Venture', ': Space Wagon',
#        ': Frontera', ': 110207', ': 31519', ': 21044i', ': Terrano',
#        ': Corvette', ': Captiva', ': Fairlane', ': 21053', ': Pride',
#        ': i20', ': Avalanche', ': Everest', ': Beetle', ': 110307', ': 3',
#        ': S 600', ': Tiida', ': Mondeo', ': S2', ': /8', ': Vesta',
#        ': Explorer', ': K1500', ': E 300', ': Aurion', ': Doblo', ': M4',
#        ': Sprinter', ': Niva Urban', ': 2123', ': ЗИМ', ': Montero',
#        ': Altima', ': Caddy', ': X-Ray', ': G2X', ': Tacoma', ': А4',
#        ': Fox', ': Caravan', ': G', ': Cerato', ': Impala', ': Camaro',
#        ': Atos', ': C 240', ': E 240', ': 31622', ': Pajero', ': Tucson',
#        ': Vesta SW', ': 6', ': IQ', ': Evanda', ': /8 Coupe', ': Onix',
#        ': LE Mans', ': Calibra', ': E 320', ': 100NX', ': Avalon',
#        ': Flex', ': Gran Turismo', ': Siber', ': Sorento', ': 324',
#        ': 3000 GT', ': 315', ': A 180', ': Optima', ': Orlando',
#        ': Trans Sport', ': Metro', ': Tuscani', ': EC3', ': Vanette',
#        ': Tipo', ': 20М', ': 3909', ': Kadett D', ': Maverick', ': 39625',
#        ': 735', ': Celica', ': Regata', ': 2', ': Vaneo', ': 2717',
#        ': Tracker', ': Econoline', ': 21150i', ': 21150', ': Sport Trac',
#        ': 2120', ': 1500', ': Suburban', ': CL 500', ': Mx-5', ': 508',
#        ': 818 Kombi', ': 2217', ': Monza', ': Avensis Wagon', ': 31602',
#        ': Grandeur', ': 410', ': 2834 DJ', ': Grand Starex',
#        ': El Camino', ': Lumina', ': 27171', ': HHR', ': Menlo', ': 2129',
#        ': Passat CC', ': М1', ': Tempo', ': 21074i', ': L300',
#        ': Premacy', ': V 200', ': Tiggo 8 Pro', ': Bronco', ': 1000',
#        ': M5', ': Bel Air', ': Viano', ': Focus', ': Malibu', ': S5',
#        ': Porter', ': А8', ': 330', ': Teana', ': Santa FE',
#        ': Corolla II', ': ML 320', ': iEVA50', ': 240SX', ': Vivaro',
#        ': 540', None, ': C 320', ': E 55 AMG', ': Pro Cee&rsquo;d',
#        ': Land Cruiser', ': Equus', ': Soul', ': H 100', ': Qashqai',
#        ': Seagull', ': Bora', ': Zafira', ': CLS 55 AMG', ': Cabrio',
#        ': Lancer', ': Pick UP', ': LUV D-Max', ': 650', ': LS400',
#        ': E 420', ': S 350', ': Jetta 1', ': 2329', ': X-Trail',
#        ': Yuan Up', ': Qin Plus', ': Mx-6', ': Tiggo 7 Pro', ': Carens',
#        ': Deepal SL03', ': S 320', ': S 550', ': S 400', ': Creta',
#        ': Kodiaq', ': Song Plus EV Champion', ': Land Cruiser Prado',
#        ': Chazor', ': Fusion', ': MR-S', ': S7',
#        ': Song Pro DM-i Champion', ': K5', ': Equinox', ': Jolion',
#        ': P7', ': Trailblazer', ': Corolla Levin', ': K2700',
#        ': Deepal S7', ': C11 EV', ': Song Plus DM-i Champion', ': X6',
#        ': Fiorino', ': 001', ': CLS 500', ': S 450', ': Tavera',
#        ': Five Hundred', ': 335', ': GX460', ': Model 3', ': Tahoe',
#        ': C 300', ': Land Cruiser 150', ': G 63 AMG',
#        ': Land Cruiser 200', ': FJ Cruiser', ': L8', ': X3', ': Model X',
#        ': C 350', ': Palisade', ': G 400', ': L7', ': Han', ': E 400',
#        ': RX330', ': Model Y', ': D-Max Irbis', ': X5', ': eS6', ': Cami',
#        ': Genesis', ': Tang', ': E 350', ': L6', ': LX570', ': V 220',
#        ': Prado', ': C 63 AMG', ': CLK 63 AMG', ': Stinger', ': Song MAX',
#        ': D-Max Oksus', ': G 320', ': CrossPolo', ': HS', ': GL 500',
#        ': GS350', ': H9', ': Multivan', ': 007', ': RX450h', ': Gol',
#        ': G 500', ': L9', ': Highlander', ': CLK 200', ': G 55 AMG',
#        ': Coupe', ': Q7', ': Patrol', ': 4runner', ': X5 M', ': Sienna',
#        ': X1', ': LS460', ': Cayenne', ': Z3', ': M6', ': X',
#        ': CLS 63 AMG', ': Mustang', ': Yuan Pro', ': GL 450',
#        ': ML 55 AMG', ': Sequoia', ': X6 M', ': X7', ': ML 400',
#        ': ML 500', ': 550', ': 750', ': GLK 220', ': 328', ': i30',
#        ': NF', ': NV200', ': E2', ': RAV 4', ': Veracruz', ': 745',
#        ': Crown Victoria', ': Land Cruiser 80', ': IS300', ': Rush',
#        ': ML 350', ': Cee&#039;d', ': 3164', ': Galloper', ': Seal',
#        ': EU5', ': 760', ': C 55 AMG', ': Z4', ': Z4M', ': Supra',
#        ': Boxster', ': RX350', ': RX300', ': Model S', ': Taycan',
#        ': E 430', ': G 300', ': Q5', ': C 220', ': LX470', ': S 63 AMG',
#        ': ES300', ': eS8', ': Hilux', ': GL 420', ': Ioniq', ': 523',
#        ': G3', ': 21217 Niva', ': Pajero IO', ': Land Cruiser 105',
#        ': Capital', ': Bluebird Sylphy', ': 67', ': 730', ': Dolphin',
#        ': LS430', ': Tourneo Connect', ': Outlander', ': e-2008',
#        ': E 220', ': iEV7S', ': 21Р', ': CX-7', ': GS300', ': 181',
#        ': Aion S', ': ID.4', ': Alphard', ': Corrado', ': S-10',
#        ': Touareg', ': Celta', ': Sedona', ': 12 ЗИМ', ': Aion S Plus',
#        ': Aion S Max', ': Aion V', ': Lavita', ': iEVS4', ': H6',
#        ': C10 EV', ': Lite Ace', ': Pajero Sport', ': Outlander XL',
#        ': SL 320', ': Golf III', ': ES350', ': C 250', ': Pathfinder',
#        ': 740', ': Caravelle', ': Golf VI', ': Scirocco', ': CO1 REEV',
#        ': CO1 EV', ': C16', ': C11 REEV', ': 1600', ': Expert',
#        ': Tiggo 8 Pro Max', ': C10 REEV'], dtype=object)

# %% [markdown]
# The original model column contained inconsistent representations, including numeric codes, partial names, and mixed-language values. A mapping dictionary was created to standardize these into unified car names and extract brand information, improving feature quality for modeling.

# %%
model_to_name = {

    # LADA (VAZ)
    "2101": "Lada 2101",
    "2102": "Lada 2102",
    "2103": "Lada 2103",
    "2104": "Lada 2104",
    "2105": "Lada 2105",
    "2106": "Lada 2106",
    "2107": "Lada 2107",
    "2108": "Lada Samara 2108",
    "2109": "Lada Samara 2109",
    "21099": "Lada Samara 21099",
    "21011": "Lada 21011",
    "21013": "Lada 21013",
    "21061": "Lada 21061",
    "21063": "Lada 21063",
    "21071": "Lada 21071",
    "21073": "Lada 21073",
    "21083": "Lada Samara 21083",
    "21093": "Lada Samara 21093",
    "2121 Нива": "Lada Niva",
    "21214 Niva": "Lada Niva 21214",
    "4x4": "Lada Niva 4x4",
    "Kalina": "Lada Kalina",
    "1117 Kalina универсал": "Lada Kalina Wagon",
    "1118 Kalina седан": "Lada Kalina Sedan",
    "1119 Kalina хэтчбэк": "Lada Kalina Hatchback",
    "2110": "Lada 2110",
    "2111": "Lada 2111",
    "2112": "Lada 2112",
    "2113": "Lada 2113",
    "2114": "Lada 2114",
    "2115": "Lada 2115",
    "21124": "Lada 21124",
    "21106": "Lada 21106",

    # GAZ (Volga / UAZ style)
    "24": "GAZ 24 Volga",
    "2410": "GAZ 2410 Volga",
    "2401": "GAZ 2401",
    "2402": "GAZ 2402",
    "3102": "GAZ 3102 Volga",
    "31029": "GAZ 31029",
    "3110": "GAZ 3110",
    "3102i": "GAZ 3102i",

    #  MOSKVICH / IZH
    "412": "Moskvich 412",
    "412 Э": "Moskvich 412",
    "2140": "Moskvich 2140",
    "2141": "Moskvich 2141",
    "21412": "Moskvich 21412",
    "ASLK 2140": "Moskvich 2140",
    "ASLK 2137": "Moskvich 2137",
    "2137 Kombi": "Moskvich 2137 Kombi",
    "2136 Kombi": "Moskvich 2136 Kombi",

    # 🟢 DAEWOO (very important in Uzbekistan)
    "Matiz": "Daewoo Matiz",
    "Nexia": "Daewoo Nexia",
    "Damas": "Daewoo Damas",
    "Tico": "Daewoo Tico",
    "Espero": "Daewoo Espero",

    #  CHEVROLET (UzAuto)
    "Lacetti": "Chevrolet Lacetti",
    "Gentra": "Chevrolet Gentra",
    "Cobalt": "Chevrolet Cobalt",
    "Spark": "Chevrolet Spark",
    "Malibu": "Chevrolet Malibu",
    "Tracker": "Chevrolet Tracker",
    "Onix": "Chevrolet Onix",
    "Captiva": "Chevrolet Captiva",

    # HYUNDAI
    "Sonata": "Hyundai Sonata",
    "Accent": "Hyundai Accent",
    "Elantra": "Hyundai Elantra",

    # KIA
    "Rio": "Kia Rio",
    "Sportage": "Kia Sportage",

    # VOLKSWAGEN
    "Passat": "Volkswagen Passat",
    "Golf": "Volkswagen Golf",
    "Golf III": "Volkswagen Golf III",
    "Golf VI": "Volkswagen Golf VI",
    "Jetta": "Volkswagen Jetta",
    "Transporter": "Volkswagen Transporter",
    "Scirocco": "Volkswagen Scirocco",

    #  NISSAN
    "Maxima": "Nissan Maxima",
    "Skyline GT-R": "Nissan Skyline GT-R",
    "Bluebird": "Nissan Bluebird",
    "R Nessa": "Nissan R'nessa",
    "Pathfinder": "Nissan Pathfinder",

    #  TOYOTA
    "Corolla": "Toyota Corolla",
    "Camry": "Toyota Camry",
    "Hiace": "Toyota Hiace",
    "Lite Ace": "Toyota LiteAce",

    #  FORD
    "Escort": "Ford Escort",
    "Fiesta": "Ford Fiesta",
    "Scorpio": "Ford Scorpio",

    # MERCEDES-BENZ
    "190": "Mercedes-Benz 190",
    "C 250": "Mercedes-Benz C250",
    "SL 320": "Mercedes-Benz SL320",

    # BMW
    "520": "BMW 520",

    # HONDA
    "Civic": "Honda Civic",

    # OPEL
    "Vectra": "Opel Vectra",
    "Omega": "Opel Omega",
    "Ascona": "Opel Ascona",
    "Rekord": "Opel Rekord",

    # FIAT
    "Uno": "Fiat Uno",
    "Croma": "Fiat Croma",

    # UAZ
    "469": "UAZ 469",
    "469Б": "UAZ 469",
    "3151": "UAZ 3151",
    "3159": "UAZ 3159",
    "3303": "UAZ 3303",
    "2206": "UAZ 2206",

    # ZAZ
    "968": "ZAZ 968",
    "968M": "ZAZ 968M",
    "1102 Таврия": "ZAZ Tavria",
    "1102": "ZAZ Tavria",
    "1111 Ока": "ZAZ Oka",

    # garbage / unknown
    "Прочее": None,
    "Другая": None,
}

# %%
brand_map = {

    # Daewoo
    "Tico": "Daewoo",
    "Matiz": "Daewoo",
    "Nexia": "Daewoo",
    "Damas": "Daewoo",
    "Espero": "Daewoo",

    # Chevrolet (UzAuto)
    "Lacetti": "Chevrolet",
    "Spark": "Chevrolet",
    "Cobalt": "Chevrolet",
    "Malibu": "Chevrolet",
    "Tracker": "Chevrolet",
    "Onix": "Chevrolet",
    "Gentra": "Chevrolet",
    "Captiva": "Chevrolet",

    # Volkswagen
    "Passat": "Volkswagen",
    "Golf": "Volkswagen",
    "Golf III": "Volkswagen",
    "Golf VI": "Volkswagen",
    "Jetta": "Volkswagen",
    "Transporter": "Volkswagen",
    "Scirocco": "Volkswagen",

    # Nissan
    "Maxima": "Nissan",
    "Skyline GT-R": "Nissan",
    "Bluebird": "Nissan",
    "R Nessa": "Nissan",
    "Pathfinder": "Nissan",

    # Hyundai
    "Sonata": "Hyundai",
    "Accent": "Hyundai",
    "Elantra": "Hyundai",

    # Kia
    "Rio": "Kia",
    "Sportage": "Kia",

    # Toyota
    "Corolla": "Toyota",
    "Camry": "Toyota",
    "Hiace": "Toyota",
    "Lite Ace": "Toyota",

    # Ford
    "Escort": "Ford",
    "Fiesta": "Ford",
    "Scorpio": "Ford",

    # Mercedes-Benz
    "190": "Mercedes-Benz",
    "C 250": "Mercedes-Benz",
    "SL 320": "Mercedes-Benz",

    # BMW
    "520": "BMW",

    # Opel
    "Vectra": "Opel",
    "Omega": "Opel",
    "Ascona": "Opel",
    "Rekord": "Opel",

    # Fiat
    "Uno": "Fiat",
    "Croma": "Fiat",

    # UAZ
    "469": "UAZ",
    "469Б": "UAZ",
    "3151": "UAZ",
    "3159": "UAZ",
    "3303": "UAZ",
    "2206": "UAZ",

    # ZAZ
    "968": "ZAZ",
    "968M": "ZAZ",
    "1102 Таврия": "ZAZ",
    "1102": "ZAZ",
    "1111 Ока": "ZAZ",

    # Moskvich / IZH
    "412": "Moskvich",
    "412 Э": "Moskvich",
    "2140": "Moskvich",
    "2141": "Moskvich",
    "21412": "Moskvich",
    "ASLK 2140": "Moskvich",
    "ASLK 2137": "Moskvich",
    "2137 Kombi": "Moskvich",
    "2136 Kombi": "Moskvich",

    # GAZ
    "24": "GAZ",
    "2410": "GAZ",
    "2401": "GAZ",
    "2402": "GAZ",
    "3102": "GAZ",
    "31029": "GAZ",
    "3110": "GAZ",
    "3102i": "GAZ",

    # Lada (VAZ)
    "2101": "Lada",
    "2102": "Lada",
    "2103": "Lada",
    "2104": "Lada",
    "2105": "Lada",
    "2106": "Lada",
    "2107": "Lada",
    "2108": "Lada",
    "2109": "Lada",
    "21011": "Lada",
    "21013": "Lada",
    "21051": "Lada",
    "21061": "Lada",
    "21071": "Lada",
    "21073": "Lada",
    "21083": "Lada",
    "21093": "Lada",
    "21099": "Lada",

    "2110": "Lada",
    "2111": "Lada",
    "2113": "Lada",
    "21106": "Lada",
    "21124": "Lada",

    "2121 Нива": "Lada",
    "21214 Niva": "Lada",
    "4x4": "Lada",

    "1117 Kalina универсал": "Lada",
    "1118 Kalina седан": "Lada",
    "1119 Kalina хэтчбэк": "Lada",

    # fallback garbage
    "Прочее": None,
    "Другая": None,
}

# %%
df['model_clean'] = df['model'].str.replace(":","", regex=False).str.strip()
df['car_name'] = df['model_clean'].map(model_to_name)

# %%
def assign_brand(model):
    if model.isdigit():
        num = int(model)

        if 2100 <= num <= 2199:
            return 'Lada'
        
        elif num in [24, 31, 3102, 31029, 3110]:
            return 'GAZ'
        
        elif num in [80, 100, 200, 50]:
            return 'Audi'
        
        elif num in [2140, 2141, 412]:
            return 'Moskvich'
    return None
def get_brand(model):
    model = str(model)

    brand = assign_brand(model)
    if brand:
        return brand
    
    for key in brand_map:
        if key.lower()in model.lower():
            return brand_map[key]
    return "Other"

# %%
df["brand"] = df["model_clean"].apply(get_brand)
df["car_name"] = df["car_name"].fillna(df["model_clean"])

# %% [markdown]
# - `groupby()` is used to find model names to find common brands based on model names
# - Not all data points are equally important — high-frequency categories contribute most to model performance.

# %%
df.groupby('model_clean')['model_clean'].count().sort_values(ascending=False)
# Out:
# model_clean
# Nexia      6536
# Lacetti    5154
# Matiz      4363
# Damas      3934
# Cobalt     3918
#            ...
# Lavita        1
# Laurel        1
# 21312         1
# 2138          1
# 410           1
# Name: model_clean, Length: 720, dtype: int64

# %%
counts = df.groupby('brand')['brand'].count().sort_values().tail(7)

ax = counts.plot(kind='barh', figsize=(10, 8))

for i, v in enumerate(counts):
    ax.text(v + 50, i, str(v), va='center')

plt.title("Number of Cars by Brand")
plt.xlabel("Count")
plt.ylabel("Brand")
plt.show()

# %%
df['brand'] = df['brand'].fillna('Other')

# %%
df.tail(100)
# Out:
#                                                      url posting_date  \
# 47006  https://olx.uz/d/obyavlenie/chery-7-pro-premiu...   10.05.2025
# 47007  https://olx.uz/d/obyavlenie/swm-g05-pro-propan...   09.05.2025
# 47008  https://olx.uz/d/obyavlenie/aktsiya-elektro-mo...   09.05.2025
# 47009  https://olx.uz/d/obyavlenie/leapmotor-c10-ev-5...   13.05.2025
# 47010  https://olx.uz/d/obyavlenie/kaptiva-5-primer-f...   14.05.2025
# ...                                                  ...          ...
# 47101  https://olx.uz/d/obyavlenie/kia-bongo-2023-sot...   15.04.2025
# 47102  https://olx.uz/d/obyavlenie/inavate-elektro-mo...   13.05.2025
# 47103  https://olx.uz/d/obyavlenie/malibu-2-turbo-pri...   13.05.2025
# 47104  https://olx.uz/d/obyavlenie/treaker-2-premier-...   10.05.2025
# 47105  https://olx.uz/d/obyavlenie/malibu-2-alo-xolat...   08.05.2025
#
#              region                   district      price currency  \
# 47006  Surkhandarya                  Sariasiya    23500..     None
# 47007         Navoi                      Navoi    23500..     None
# 47008       Bukhara                     Buhara    23500..     None
# 47009      Tashkent  TashkentAlmazarskiy rayon    23200..     None
# 47010   Kashkadarya                      Kitab    23000..     None
# ...             ...                        ...        ...      ...
# 47101       Bukhara                     Buhara  300000000      UZS
# 47102  Surkhandarya                     Termez  300000000      UZS
# 47103       Khorezm                     Karaul  300000000      UZS
# 47104         Navoi                      Navoi  300000000      UZS
# 47105  Surkhandarya                  Sariasiya  280000000      UZS
#
#                                              description  \
# 47006  Moshin yangi xolatda bir tomchi keraska xam yo...
# 47007  Машина хорошая не битая очень красивая фарик х...
# 47008  Исталган ранг ярашадиган электромобил қайси?!\...
# 47009  Leapmotor C10 EV 530km \nОфициальная гарантия\...
# 47010  Каптива без пробег мишлен балон ,⁷ тонировка ,...
# ...                                                  ...
# 47101  Propan òrnatilgan\nFurgon qilingan\nKandisione...
# 47102  Mashina ideal oq rangi qiziriq tumanida inavat...
# 47103  Йили 2019 пробег 81800 янги краска йук нархи 2...
# 47104  Mashina.   Yangi.   Salondan.   Chiqanganiga e...
# 47105  Kraska toza \n4 ta yumshoq balon\nMator, xadav...
#
#                                                image_url seller_type  \
# 47006  https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private
# 47007  https://frankfurt.apollo.olxcdn.com:443/v1/fil...        None
# 47008  https://frankfurt.apollo.olxcdn.com:443/v1/fil...        None
# 47009  https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private
# 47010  https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private
# ...                                                  ...         ...
# 47101  https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private
# 47102  https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private
# 47103  https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private
# 47104  https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private
# 47105  https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private
#
#                          model  ... transmission  color  engine_volume  \
# 47006                 : Прочее  ...    Automatic  White             16
# 47007                 : Прочее  ...    Automatic  Black             10
# 47008  : Song Plus EV Champion  ...    Automatic  White            220
# 47009                 : C10 EV  ...    Automatic  Black              1
# 47010                : Captiva  ...    Automatic  Black             15
# ...                        ...  ...          ...    ...            ...
# 47101                 : Другая  ...       Manual  White             80
# 47102                 : Другая  ...    Automatic  White              3
# 47103                 : Malibu  ...    Automatic  Black              2
# 47104                : Tracker  ...    Automatic  Black             12
# 47105                 : Malibu  ...    Automatic  Black             15
#
#           fuel_type  condition owners_count  \
# 47006  Gasoline/Gas  Excellent            1
# 47007  Gasoline/Gas  Excellent            1
# 47008      Electric  Excellent            1
# 47009      Electric  Excellent         None
# 47010      Gasoline  Excellent            1
# ...             ...        ...          ...
# 47101  Gasoline/Gas  Excellent           4+
# 47102      Electric  Excellent            1
# 47103  Gasoline/Gas  Excellent            2
# 47104      Gasoline  Excellent           4+
# 47105      Gasoline  Excellent            1
#
#                                       additional_options  \
# 47006                                    Customs Cleared
# 47007  Security System, Electrical Window Lifters, Па...
# 47008  Customs Cleared, Electrical Mirrors, Electrica...
# 47009  Customs Cleared, Electrical Mirrors, Electrica...
# 47010  Парктроник, Electrical Mirrors, Customs Cleare...
# ...                                                  ...
# 47101  Парктроник, Electrical Mirrors, Customs Cleare...
# 47102                                               None
# 47103                                    Air Conditioner
# 47104  Air Conditioner, Electrical Mirrors, Парктрони...
# 47105  Парктроник, Electrical Mirrors, Security Syste...
#
#                  model_clean               car_name      brand
# 47006                 Прочее                 Прочее      Other
# 47007                 Прочее                 Прочее      Other
# 47008  Song Plus EV Champion  Song Plus EV Champion      Other
# 47009                 C10 EV                 C10 EV      Other
# 47010                Captiva      Chevrolet Captiva  Chevrolet
# ...                      ...                    ...        ...
# 47101                 Другая                 Другая      Other
# 47102                 Другая                 Другая      Other
# 47103                 Malibu       Chevrolet Malibu  Chevrolet
# 47104                Tracker      Chevrolet Tracker  Chevrolet
# 47105                 Malibu       Chevrolet Malibu  Chevrolet
#
# [100 rows x 24 columns]

# %%
df
# Out:
#                                                      url posting_date  \
# 0      https://olx.uz/d/obyavlenie/vaz-2103-gazda-yur...   26.04.2025
# 1      https://olx.uz/d/obyavlenie/vaz2105zhuguli-god...   26.04.2025
# 2      https://olx.uz/d/obyavlenie/juguli-21011-sotil...   26.04.2025
# 3      https://olx.uz/d/obyavlenie/waxzod-kafolati-bi...   26.04.2025
# 4      https://olx.uz/d/obyavlenie/mazda-626-starushk...   26.04.2025
# ...                                                  ...          ...
# 47101  https://olx.uz/d/obyavlenie/kia-bongo-2023-sot...   15.04.2025
# 47102  https://olx.uz/d/obyavlenie/inavate-elektro-mo...   13.05.2025
# 47103  https://olx.uz/d/obyavlenie/malibu-2-turbo-pri...   13.05.2025
# 47104  https://olx.uz/d/obyavlenie/treaker-2-premier-...   10.05.2025
# 47105  https://olx.uz/d/obyavlenie/malibu-2-alo-xolat...   08.05.2025
#
#                region       district      price currency  \
# 0             Jizzakh      Gallaaral   15000000      UZS
# 1            Namangan       Namangan   15000000      UZS
# 2             Khorezm         Karaul   15000000      UZS
# 3             Jizzakh  Mardzhanbulak   15000000      UZS
# 4      Karakalpakstan        Kungrad   15000000      UZS
# ...               ...            ...        ...      ...
# 47101         Bukhara         Buhara  300000000      UZS
# 47102    Surkhandarya         Termez  300000000      UZS
# 47103         Khorezm         Karaul  300000000      UZS
# 47104           Navoi          Navoi  300000000      UZS
# 47105    Surkhandarya      Sariasiya  280000000      UZS
#
#                                              description  \
# 0              Mator karobka zadnimos qilingan yili 1979
# 1      Торг строга укапота машина на ходу  полный раб...
# 2      Mashin toxlangan metan 100 lik  bo 14  diska b...
# 3      31029 96yil matori zor karopka zor magnitafon ...
# 4      Прадаётсья на запчасти Мазда 626 старушка 1.6 ...
# ...                                                  ...
# 47101  Propan òrnatilgan\nFurgon qilingan\nKandisione...
# 47102  Mashina ideal oq rangi qiziriq tumanida inavat...
# 47103  Йили 2019 пробег 81800 янги краска йук нархи 2...
# 47104  Mashina.   Yangi.   Salondan.   Chiqanganiga e...
# 47105  Kraska toza \n4 ta yumshoq balon\nMator, xadav...
#
#                                                image_url seller_type  \
# 0      https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private
# 1      https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private
# 2      https://frankfurt.apollo.olxcdn.com:443/v1/fil...        None
# 3      https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private
# 4      https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private
# ...                                                  ...         ...
# 47101  https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private
# 47102  https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private
# 47103  https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private
# 47104  https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private
# 47105  https://frankfurt.apollo.olxcdn.com:443/v1/fil...     private
#
#            model  ... transmission  color  engine_volume     fuel_type  \
# 0         : 2103  ...       Manual    Red             12  Gasoline/Gas
# 1         : 2105  ...       Manual  Green              1  Gasoline/Gas
# 2         : 2101  ...       Manual  White           2103  Gasoline/Gas
# 3        : 31029  ...       Manual  White            105  Gasoline/Gas
# 4          : 626  ...       Manual  White             16  Gasoline/Gas
# ...          ...  ...          ...    ...            ...           ...
# 47101   : Другая  ...       Manual  White             80  Gasoline/Gas
# 47102   : Другая  ...    Automatic  White              3      Electric
# 47103   : Malibu  ...    Automatic  Black              2  Gasoline/Gas
# 47104  : Tracker  ...    Automatic  Black             12      Gasoline
# 47105   : Malibu  ...    Automatic  Black             15      Gasoline
#
#           condition owners_count  \
# 0              Good            2
# 1           Average            1
# 2              Good           4+
# 3              Good            2
# 4      Needs Repair         None
# ...             ...          ...
# 47101     Excellent           4+
# 47102     Excellent            1
# 47103     Excellent            2
# 47104     Excellent           4+
# 47105     Excellent            1
#
#                                       additional_options model_clean  \
# 0                                                   None        2103
# 1                                                   None        2105
# 2                                                   None        2101
# 3                                                   None       31029
# 4      Customs Cleared, Electrical Window Lifters, Па...         626
# ...                                                  ...         ...
# 47101  Парктроник, Electrical Mirrors, Customs Cleare...      Другая
# 47102                                               None      Другая
# 47103                                    Air Conditioner      Malibu
# 47104  Air Conditioner, Electrical Mirrors, Парктрони...     Tracker
# 47105  Парктроник, Electrical Mirrors, Security Syste...      Malibu
#
#                 car_name      brand
# 0              Lada 2103       Lada
# 1              Lada 2105       Lada
# 2              Lada 2101       Lada
# 3              GAZ 31029        GAZ
# 4                    626      Other
# ...                  ...        ...
# 47101             Другая      Other
# 47102             Другая      Other
# 47103   Chevrolet Malibu  Chevrolet
# 47104  Chevrolet Tracker  Chevrolet
# 47105   Chevrolet Malibu  Chevrolet
#
# [47106 rows x 24 columns]

# %%
## copy
fix_model = df.copy()

# %%
df['body_type'].unique()
# Out:
# array(['Sedan', 'Convertible', 'Station Wagon', 'Hatchback', 'Other',
#        'SUV', 'Pickup', 'Minivan', 'Coupe'], dtype=object)
